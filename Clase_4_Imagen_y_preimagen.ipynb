# %%
 Imagen y preimagen

# %% [markdown]
#  **FUNCIONES MATEMATICAS: IMAGEN Y PREIMAGEN**🤓
#
#  Los conceptos de imagen y preimagen son fundamentales para entender cómo las funciones relacionan conjuntos entre sí.
#
# *** Imagen de una Función***
#
#
# La imagen de una función
# 𝑓
# f, denotada como
# 𝑓
# (
# 𝐴
# )
# f(A), es el conjunto de todos los valores que la función puede producir cuando sus argumentos pertenecen al conjunto de partida
# 𝐴
# A. Formalmente, se define como:
#
# 𝑓
# (
# 𝐴
# )
# =
# {
# 𝑓
# (
# 𝑥
# )
# ∣
# 𝑥
# ∈
# 𝐴
# }
# f(A)={f(x)∣x∈A}
#
#
#
#
# *   Ejemplo: Considera la función
# 𝑓
# :
# 𝑅
# →
# 𝑅
# f:R→R dada por
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=x
# 2
#
#
#
# *   Si tomamos el conjunto
# 𝐴
# =
# {
# −
# 2
# ,
# −
# 1
# ,
# 0
# ,
# 1
# ,
# 2
# }
# A={−2,−1,0,1,2}, entonces la imagen de
# 𝐴
# A bajo
# 𝑓
# f, denotada como
# 𝑓
# (
# 𝐴
# )
# f(A), sería:
# 𝑓
# (
# 𝐴
# )
# =
# {
# 0
# ,
# 1
# ,
# 4
# }
# f(A)={0,1,4}
#
# ***Preimagen de una Función ***
#
# f
# −1
#  (B)={x∈X∣f(x)∈B}
#
# Ejemplo: Usando la misma función
# 𝑓
# :
# 𝑅
# →
# 𝑅
# f:R→R dada por
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=x
# 2
#
#
#  .
# Si consideramos el conjunto
# 𝐵
# =
# {
# 0
# ,
# 1
# }
# B={0,1}, entonces la preimagen de
# 𝐵
# B bajo
# 𝑓
# f, denotada como
# 𝑓
# −
# 1
# (
# 𝐵
# )
# f
# −1
#  (B), sería:
# 𝑓
# −
# 1
# (
# 𝐵
# )
# =
# {
# −
# 1
# ,
# 0
# ,
# 1
# }
# f
# −1
#  (B)={−1,0,1}
# Esto se debe a que
# 𝑓
# (
# −
# 1
# )
# =
# 1
# f(−1)=1,
# 𝑓
# (
# 0
# )
# =
# 0
# f(0)=0 y
# 𝑓
# (
# 1
# )
# =
# 1
# f(1)=1.
#
# ***CLASES***🤓✍️
# 1. f(x)=3x
#
# A,B Conjuntos
#
# Una funcion de A B es una regla de asociacion que a cada elemento x E A ,le asocia un unico elemento y E B, al que se lo denomina imagen de x a travez de f
# y se lo denota y=f(x)
#
#
# A->B
#
# F:X->y=f(x)
#
# f: R->R
#
#  1. ejemplo
#
#  f(x)=3x
#
# ∩={Palabras en castellano}
#
#  ∆= { a, b,....}
#
#  ∆
#      ∩->∆
#  I:
#      ∞->I(∞) = Letra inicial de cada palabra.
#
#   I(marsupial)=m
#
#   ∀x E A Ǝ!yE B+q
#
#   y=f(x)
#
# (R,≤,+,X)    RXR={(X,Y): XER, Y E R}
#     RXR
# +:
#     (X,y)->+(X,y)=x+y
#
#       R2-> R
#   X:
#       (X,y)->x(x,y)= xy
#
#       R^2->(0,1)
#
#   R≤:(X,Y)->R≤(X,Y)=1 Si x ≤ y
#
#                   =si no
#
#
# R^N={(xi),EN    :∀iEN, Xi E R}
#
#      =(X1,X2.X3..)
#
#      (2,4,6,8...)
#
# P;N*->N*
#
# P:n->p(n)=2n
#
# X: N->R ; n->  X(n)=1/n^2+1 ->una frecuencia(xn) n E N es una funcion que pate de N
#
# X0=1,  x1,= 1/2, x2=1/5
#
#
#   X E A-F-> Y=F(X)EB
#
#   ![WhatsApp Image 2024-06-30 at 6.31.59 PM.jpeg](data:image/jpeg;base64,...)
#
#   Y E B
#
#   {Y} ⊆ B
#
#       f^-1
#  (Y)=
#
#
#  ![WhatsApp Image 2024-06-30 at 6.45.49 PM.jpeg](data:image/jpeg;base64,...)
#
#  F:R->R
#  F:X-> X^2 + 1
#  f(R)=)1,+∞(
# f-1(}-10,0{)={XER: F(x) E)-10,0(}
#
# =Conj vacio = f-1(0,2)
#
#              ={xER:x^2+1{0,2}}
#
#              ={xER: 0≤X^2+1≤2}
#
#              ={XER:-1≤X^2 ≤ 1}
#
#              =XER:-1≤X≤1}
#
#
#   F^-1({0,})={-1,1}
#
#   ![WhatsApp Image 2024-06-30 at 7.09.43 PM.jpeg](data:image/jpeg;base64,...)
